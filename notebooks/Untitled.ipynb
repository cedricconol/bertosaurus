# %%
import bertosaurus
# import warnings
# warnings.filterwarnings('ignore')
import spacy

# %%
import torch

# %%
torch.cuda.empty_cache()

# %%
a = spacy.load('en_trf_bertbaseuncased_lg')
# Out:
# 2020-08-21 08:58:24.655 INFO    transformers.configuration_utils: loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-config.json from cache at /home/cedric/.cache/torch/transformers/4dad0251492946e18ac39290fcfe91b89d370fee250efe9521476438fe8ca185.7156163d5fdc189c3016baca0775ffce230789d7fa2a42ef516483e4ca884517
# 2020-08-21 08:58:24.660 INFO    transformers.configuration_utils: Model config BertConfig {
#   "_num_labels": 2,
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bad_words_ids": null,
#   "bos_token_id": null,
#   "decoder_start_token_id": null,
#   "do_sample": false,
#   "early_stopping": false,
#   "eos_token_id": null,
#   "finetuning_task": null,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "LABEL_0",
#     "1": "LABEL_1"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
# ...

# %%
sentence='I want to change the world'
word='change'

# %%
import streamlit

# %%
bertosaurus.ranked_synonyms(sentence, word)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-19627bb2166e> in <module>
# ----> 1 bertosaurus.ranked_synonyms(sentence, word)
#
# /media/cedric/518465B679803420/projects/bertosaurus/src/bertosaurus/functions.py in ranked_synonyms(sentence, word, nlp, bert)
#      67 def ranked_synonyms(sentence, word, nlp=None, bert=None):
#      68     if not bert:
# ---> 69         bert = load_model("en_trf_bertbaseuncased_lg")
#      70
#      71     if not nlp:
#
# /media/cedric/518465B679803420/projects/bertosaurus/src/bertosaurus/functions.py in load_model(name)
#      35
#      36 def load_model(name):
# ---> 37     return spacy.load(name)
#      38
#      39
#
# ~/anaconda3/lib/python3.7/site-packages/spacy/__init__.py in load(name, **overrides)
#      28     if depr_path not in (True, False, None):
# ...
